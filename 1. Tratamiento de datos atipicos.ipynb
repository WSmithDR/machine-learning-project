# %% [markdown]
# <a href="https://colab.research.google.com/github/WSmithDR/machine-learning-project/blob/main/Proyecto_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Datos atípicos

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df_train = pd.read_csv('datos/inicial/vehiculos_train.csv')
df_test = pd.read_csv('datos/inicial/vehiculos_test.csv')

# %%
#distribución del dataset train
df_train.hist(bins=50, figsize=(10,10))
plt.tight_layout()
plt.show()

# %%
df_train.columns
# Out:
# Index(['marca', 'modelo', 'color', 'anio_registro', 'tipo_vehiculo',
#        'millas_recorridas', 'tamanio_motor', 'transmision', 'tipo_combustible',
#        'precio_vehiculo', 'num_asientos', 'num_puertas', 'problema_averia',
#        'id_problema_averia', 'fecha_averia', 'complejidad_reparacion',
#        'costo_reparacion', 'horas_reparacion', 'fecha_reparacion', 'fraude'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196429 entries, 0 to 196428
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   marca                   196429 non-null  object
#  1   modelo                  177768 non-null  object
#  2   color                   191581 non-null  object
#  3   anio_registro           191599 non-null  float64
#  4   tipo_vehiculo           196429 non-null  object
#  5   millas_recorridas       193664 non-null  float64
#  6   tamanio_motor           195482 non-null  object
#  7   transmision             196429 non-null  object
#  8   tipo_combustible        196429 non-null  object
#  9   precio_vehiculo         186867 non-null  float64
#  10  num_asientos            196429 non-null  float64
#  11  num_puertas             196429 non-null  float64
#  12  problema_averia         196429 non-null  object
#  13  id_problema_averia      196429 non-null  int64
# ...

# %%
df_train.describe()
# Out:
#        anio_registro  millas_recorridas  precio_vehiculo   num_asientos  \
# count  191599.000000       1.936640e+05     1.868670e+05  196429.000000
# mean     2012.678208       4.867635e+04     1.396373e+04       4.935590
# std         5.006846       4.004901e+04     3.307734e+04       1.072501
# min      1900.000000      -1.991700e+04    -6.967960e+05       2.000000
# 25%      2009.000000       1.464700e+04     4.795000e+03       5.000000
# 50%      2014.000000       4.000000e+04     8.999000e+03       5.000000
# 75%      2016.000000       7.557125e+04     1.697000e+04       5.000000
# max      3010.000000       1.080000e+06     9.999999e+06      20.000000
#
#          num_puertas  id_problema_averia  complejidad_reparacion  \
# count  196429.000000       196429.000000           196429.000000
# mean        4.358593            0.498511                1.366855
# std         1.031904            1.131135                0.726668
# ...

# %%
df_train_n = df_train.copy()

# %% [markdown]
# ### Anio_registro

# %%
#visualización de valores atípicos del dataset train
df_train[['anio_registro']].boxplot(figsize=(10, 10))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#visualización de valores atípicos del dataset train
df_train[['anio_registro']].groupby('anio_registro').size()
# Out:
# anio_registro
# 1900.0        1
# 1990.0       12
# 1995.0       19
# 2000.0      496
# 2001.0     1163
# 2002.0     1962
# 2003.0     2449
# 2004.0     3797
# 2005.0     4346
# 2006.0     6919
# 2007.0     8032
# 2008.0     9449
# 2009.0     9267
# 2010.0    10735
# 2011.0    10953
# 2012.0    12147
# 2013.0    12914
# 2014.0    15766
# 2015.0    20862
# 2016.0    15951
# 2017.0    19104
# 2018.0    12591
# 2019.0    12663
# 3010.0        1
# dtype: int64

# %%
#analizamos las caracteristica que tiene el carro con el anio aberrante
df_train[df_train['anio_registro']==1900.0].head()
# Out:
#           marca modelo color  anio_registro tipo_vehiculo  millas_recorridas  \
# 23716  Vauxhall  Corsa  Grey         1900.0     Hatchback                NaN
#
#       tamanio_motor transmision tipo_combustible  precio_vehiculo  \
# 23716          1.4L      Manual           Petrol           8500.0
#
#        num_asientos  num_puertas problema_averia  id_problema_averia  \
# 23716          12.0          0.0  Gear Box Issue                   0
#
#       fecha_averia  complejidad_reparacion  costo_reparacion  \
# 23716   2018-05-04                       1        626.373971
#
#        horas_reparacion fecha_reparacion  fraude
# 23716        475.223492       2018-06-01       1

# %%
#filtramos el df con las mismas caracteristicas que tiene el carro con el anio aberrante
df_train[(df_train['marca']=='Vauxhall') & (df_train['modelo']=='Corsa') & (df_train['tamanio_motor']=='1.4L') & (df_train['precio_vehiculo']==8500.0)& (df_train['color']=='Grey')].head(23)
# Out:
#           marca modelo color  anio_registro tipo_vehiculo  millas_recorridas  \
# 23716  Vauxhall  Corsa  Grey         1900.0     Hatchback                NaN
# 75841  Vauxhall  Corsa  Grey         2016.0     Hatchback            10945.0
#
#       tamanio_motor transmision tipo_combustible  precio_vehiculo  \
# 23716          1.4L      Manual           Petrol           8500.0
# 75841          1.4L      Manual           Petrol           8500.0
#
#        num_asientos  num_puertas     problema_averia  id_problema_averia  \
# 23716          12.0          0.0      Gear Box Issue                   0
# 75841           5.0          5.0  Transmission Issue                   1
#
#       fecha_averia  complejidad_reparacion  costo_reparacion  \
# 23716   2018-05-04                       1        626.373971
# 75841   2018-04-20                       1        105.500000
#
#        horas_reparacion fecha_reparacion  fraude
# 23716        475.223492       2018-06-01       1
# ...

# %%
#reemplazamos el anio de otro carro similar que tiene caracteristicas similares
df_train_n.loc[df_train_n['anio_registro'] == 1900.0, 'anio_registro'] = 2016.0

# %%
#analizamos las caracteristica que tiene el carro con el anio aberrante
df_train[df_train['anio_registro']==3010.0].head()
# Out:
#        marca    modelo color  anio_registro tipo_vehiculo  millas_recorridas  \
# 166214   BMW  7 Series  Grey         3010.0          Wood            -2038.0
#
#        tamanio_motor transmision tipo_combustible  precio_vehiculo  \
# 166214        999.0L      Hybrid         Hydrogen        -182067.0
#
#         num_asientos  num_puertas      problema_averia  id_problema_averia  \
# 166214          12.0          0.0  Excessive Emissions                   0
#
#        fecha_averia  complejidad_reparacion  costo_reparacion  \
# 166214   2018-04-15                       1            -418.0
#
#         horas_reparacion fecha_reparacion  fraude
# 166214               1.0       2018-04-15       1

# %%
#filtramos el df con las mismas caracteristicas que tiene el carro con el anio aberrante
# df_train[(df_train['marca']=='BMW') & (df_train['modelo']=='7 Series') & (df_train['tamanio_motor']=='999.0L')& (df_train['color']=='Grey')].head(23)
df_train[(df_train['marca']=='BMW') & (df_train['modelo']=='7 Series') & (df_train['color']=='Grey')].groupby('anio_registro').size().sort_values()
# Out:
# anio_registro
# 3010.0    1
# 2003.0    2
# 2006.0    2
# 2005.0    2
# 2008.0    3
# 2010.0    3
# 2015.0    3
# 2007.0    3
# 2012.0    3
# 2013.0    4
# 2011.0    4
# 2009.0    6
# 2017.0    6
# 2014.0    6
# 2018.0    8
# 2016.0    8
# 2019.0    9
# dtype: int64

# %%
#reemplazamos el anio de otro carro similar que tiene caracteristicas similares
df_train_n.loc[df_train_n['anio_registro'] == 3010.0, 'anio_registro'] = 2019.0

# %%
#visualización de valores atípicos del dataset limpio
df_train_n[['anio_registro']].boxplot(figsize=(10, 10))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## millas_recorridas

# %% [markdown]
# #### Identificación y análisis de variables numéricas
#
# Primero, identificaremos las variables numéricas del dataset de entrenamiento para comprender sus distribuciones y detectar posibles valores atípicos. Esta exploración nos permitirá:
#
# 1. Visualizar la distribución de cada variable numérica mediante histogramas
# 2. Detectar valores anómalos o outliers que puedan afectar nuestro análisis
# 3. Entender el rango y comportamiento de variables clave como 'millas_recorridas', 'precio_vehiculo' y otras
# 4. Establecer criterios para el tratamiento posterior de valores extremos o erróneos
#
# A continuación, extraeremos las columnas numéricas y analizaremos sus características principales mediante visualizaciones.

# %%
df_train_numeric.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_train_numeric.describe()
#
# NameError: name 'df_train_numeric' is not defined

# %%
df_train_numeric = df_train.select_dtypes(include=['number'])
df_test_numeric = df_test.select_dtypes(include=['number'])
df_train_numeric=df_train_numeric.loc[(df_train_numeric["anio_registro"]<2025)&(df_train_numeric['anio_registro']>=1995)&(df_train_numeric['millas_recorridas']<250000)]
df_test_numeric=df_test_numeric.loc[(df_test_numeric["anio_registro"]<2025)&(df_test_numeric['anio_registro']>=1995)&(df_test_numeric['millas_recorridas']<250000)]

# %%
df_train_numeric.loc[df_train_numeric['millas_recorridas']<0,['millas_recorridas','fraude']].hist(bins=50, figsize=(8,8))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df_train_numeric.loc[df_train_numeric['millas_recorridas']==0,['millas_recorridas','fraude']].hist(bins=50, figsize=(8,8))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df_train_numeric.loc[df_train_numeric['millas_recorridas']>0,['millas_recorridas','fraude','anio_registro']].hist(bins=50, figsize=(8,8))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# La mayoria de los casos de fraudes están registrados en las millas recorridas negativas por lo que eliminarlos no son una opción. Vemos que en los vehiculos cero millas, solo se ha registrado un caso de fraude, el resto presumiblemente fueron vehiculos que llegaron defectos de frábica, por lo que el cero no se corresponde a un dato atipico. Parecer ser que la mejor solucion es simplemente convertir a positivos las millas negativas, valores que estarían dentro de los rangos normales.

# %%
mask = df_train['millas_recorridas'] < 0

# %%
df_train.loc[mask, 'millas_recorridas'] = df_train.loc[mask, 'millas_recorridas'].abs()

# %%
df_test.loc[mask, 'millas_recorridas'] = df_test.loc[mask, 'millas_recorridas'].abs()

# %%
df_train['millas_recorridas'].describe()
# Out:
# count    1.936640e+05
# mean     4.868746e+04
# std      4.003550e+04
# min      0.000000e+00
# 25%      1.465575e+04
# 50%      4.000000e+04
# 75%      7.557125e+04
# max      1.080000e+06
# Name: millas_recorridas, dtype: float64

# %%
df_test['millas_recorridas'].describe()
# Out:
# count    2.151000e+04
# mean     4.920080e+04
# std      5.913809e+04
# min     -1.979300e+04
# 25%      1.447875e+04
# 50%      4.005400e+04
# 75%      7.600000e+04
# max      6.363342e+06
# Name: millas_recorridas, dtype: float64

# %% [markdown]
# ## precio_vehiculo

# %%
df_train[['precio_vehiculo']].boxplot(figsize=(5, 5))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#comparar los precio de un vehiculo en valores positivos con vehiculos que tienen precio negativo. 
df_train[(df_train['marca']=='BMW') & (df_train['modelo']=='6 Series Gran Turismo') & (df_train['tipo_vehiculo']=='Hatchback')]
# Out:
#        marca                 modelo  color  anio_registro tipo_vehiculo  \
# 1099     BMW  6 Series Gran Turismo  Black            NaN     Hatchback
# 1685     BMW  6 Series Gran Turismo   Blue         2017.0     Hatchback
# 2903     BMW  6 Series Gran Turismo  White         2017.0     Hatchback
# 5720     BMW  6 Series Gran Turismo   Grey         2017.0     Hatchback
# 9068     BMW  6 Series Gran Turismo  Black         2017.0     Hatchback
# 11302    BMW  6 Series Gran Turismo   Grey         2019.0     Hatchback
# 28455    BMW  6 Series Gran Turismo  Black         2019.0     Hatchback
# 29523    BMW  6 Series Gran Turismo   Grey         2019.0     Hatchback
# 35182    BMW  6 Series Gran Turismo  White         2017.0     Hatchback
# 46589    BMW  6 Series Gran Turismo  Black         2017.0     Hatchback
# 55069    BMW  6 Series Gran Turismo  White         2017.0     Hatchback
# 68273    BMW  6 Series Gran Turismo   Blue         2019.0     Hatchback
# ...

# %%
# Remplazar valores negativos en 'precio de vehiculo' por sui valor absoluto. 
df_train['precio_vehiculo'] = df_train['precio_vehiculo'].abs()

# %%
#Comprobamos que ya no existen valores negativos en 'precio-vehiculo'
df_train[['precio_vehiculo']].boxplot(figsize=(5, 5))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#Comprobamos que ya no existen valores negativos en 'precio-vehiculo'
df_train[['precio_vehiculo']].boxplot(figsize=(5, 5))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#ante la existencia de un valor atipico, verificamos su indice
df_train[df_train['precio_vehiculo']==df_train['precio_vehiculo'].max()]
# Out:
#           marca modelo   color  anio_registro tipo_vehiculo  \
# 177859  McLaren  675LT  Silver         2016.0         Coupe
#
#         millas_recorridas tamanio_motor transmision tipo_combustible  \
# 177859              200.0          3.8L   Automatic           Petrol
#
#         precio_vehiculo  num_asientos  num_puertas     problema_averia  \
# 177859        9999999.0           2.0          2.0  Transmission Issue
#
#         id_problema_averia fecha_averia  complejidad_reparacion  \
# 177859                   1   2017-06-09                       3
#
#         costo_reparacion  horas_reparacion fecha_reparacion  fraude
# 177859         30239.997              12.0       2017-06-12       0

# %% [markdown]
# ## costo_reparacion

# %%
#visualización de valores atípicos del dataset train
df_co = df_train[['costo_reparacion']]
# df_co[df_train['costo_reparacion'] < 0].boxplot(figsize=(10, 10))
df_train[['costo_reparacion']].boxplot(figsize=(10, 10))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#datos que tienen ruido, no deberían estar con valor negativo
df_train[df_train['costo_reparacion'] < 0].groupby(['marca','modelo','anio_registro']).size()
# Out:
# marca  modelo                 anio_registro
# BMW    6 Series               2005.0            9
#                               2009.0            1
#                               2010.0            1
#                               2011.0            3
#                               2012.0            6
#                               2013.0            5
#                               2014.0            4
#        6 Series Gran Coupe    2012.0            1
#                               2013.0            5
#                               2014.0            9
#                               2015.0            6
#                               2016.0            1
#                               2017.0            7
#                               2018.0            2
#        6 Series Gran Turismo  2017.0            6
#        7 Series               2002.0            1
#                               2003.0            1
#                               2009.0            2
# ...

# %%
#analizamos las caracteristica que tiene el carro con el anio aberrante
df_train[df_train['costo_reparacion'] < 0].head(137)
# Out:
#        marca                 modelo  color  anio_registro tipo_vehiculo  \
# 2903     BMW  6 Series Gran Turismo  White         2017.0     Hatchback
# 4266     BMW    6 Series Gran Coupe  Black         2018.0         Coupe
# 5714     BMW              Alpina D3   Blue         2007.0        Saloon
# 5720     BMW  6 Series Gran Turismo   Grey         2017.0     Hatchback
# 8535     BMW    6 Series Gran Coupe    Red         2015.0         Coupe
# ...      ...                    ...    ...            ...           ...
# 182174   BMW    6 Series Gran Coupe  White         2014.0         Coupe
# 183782   BMW               7 Series  Black         2012.0        Saloon
# 184604   BMW    6 Series Gran Coupe  White         2015.0         Coupe
# 184793   BMW    6 Series Gran Coupe  Black         2017.0         Coupe
# 186247   BMW               7 Series   Grey         2018.0        Saloon
#
#         millas_recorridas tamanio_motor transmision  \
# ...

# %% [markdown]
# ## horas_reparacion
