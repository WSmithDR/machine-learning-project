# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from constants import initial_dir

# %%
df_test = pd.read_csv(f'{initial_dir }/vehiculos_test.csv')
df_train = pd.read_csv(f'{initial_dir }/vehiculos_train.csv')

# %% [markdown]
# ## Análisis Multivariado:
# ##### 1. Elija al menos dos pares de variables (no considere la variable target) y realice un análisis multivariable para cada par.

# %% [markdown]
# ### Par 1: Análisis multivariado 'anio_registro' y 'millas recorridas'

# %%
correlaciones = df_train[['fraude','costo_reparacion','precio_vehiculo','millas_recorridas']].corr()
print(correlaciones)

# %%
# Visualizar matriz de correlación
plt.figure(figsize=(8, 6))
sns.heatmap(correlaciones, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de Correlación')
plt.tight_layout()
plt.savefig('correlaciones.png')
plt.show()

# %%
# Calculate skewness and kurtosis
skewness = df_train[['precio_vehiculo', 'costo_reparacion', 'millas_recorridas']].skew()
kurtosis = df_train[['precio_vehiculo', 'costo_reparacion', 'millas_recorridas']].kurt()

print("Skewness:\n", skewness)
print("\nKurtosis:\n", kurtosis)

# %%
sns.set(style="whitegrid")

# ========== PAR 1: anio_registro vs millas_recorridas ==========
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_train, x='anio_registro', y='millas_recorridas', alpha=0.6)
plt.title('Año de Registro vs Millas Recorridas')
plt.xlabel('Año de Registro')
plt.ylabel('Millas Recorridas')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Par 2: Análisis multivariado 'tañanio_motor' y 'costo_reparación'

# %%
# ========== PAR 2: tamanio_motor vs costo_reparacion ==========
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_train, x='tamanio_motor', y='costo_reparacion', alpha=0.6)
plt.title('Tamaño del Motor vs Costo de Reparación')
plt.xlabel('Tamaño del Motor')
plt.ylabel('Costo de Reparación')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Utilice visualizaciones adecuadas (por ejemplo, diagramas de dispersión, gráficos de barras).

# %% [markdown]
# ##### Generación de información de los datos

# %%
df_train.info()

# %% [markdown]
# ##### 2.1. Figuras de análisis multivariado para las variables numéricas

# %%
### Variables predictoras según la variable target

###### DIAGRAMAS DE CAJA
import matplotlib.pyplot as plt
import seaborn as sns
import math



df = df_train[['anio_registro','millas_recorridas','precio_vehiculo','num_asientos',
    'num_puertas','complejidad_reparacion','costo_reparacion','horas_reparacion','fraude']]

columnas = df.columns[:-1]
plt.figure(figsize=(15, 10))


for i, columna in enumerate(columnas, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(x='fraude',y=df[columna], data=df)
    plt.title(f'Boxplot de {columna} según fraude')


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2.2. Matriz de correlación entre las variables numericas con variable target

# %%
corr_matrix=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %% [markdown]
# ##### 2.3. Figuras de análisis multivariado para las variables categóricas

# %% [markdown]
# ##### Fraude según marca, color, tipode vehiculo, transmisión, tipo de combustible y problema de avería.

# %%
### Variables predictoras según la variable target

###### GRÁFICO DE BARRAS
import matplotlib.pyplot as plt
import seaborn as sns

variables_categoricas = ['marca', 'color', 'tipo_vehiculo','transmision', 'tipo_combustible', 'problema_averia']

# Graficar cada variable categórica vs. 'fraude'
for col in variables_categoricas:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df_train, x=col, hue='fraude')
    plt.title(f'Frecuencia de Fraude según {col.capitalize()}')
    plt.xlabel(col.capitalize())
    plt.ylabel('Conteo')
    plt.xticks(rotation=60, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### 3. Explique cualquier relación observada entre los pares de variables analizados.

# %% [markdown]
# ### Explicación sobre las relaciones observadas
#
# -En cuanto a las 'millas_recorridas', existen valores atípicos altos en los casos sin fraude, pero tambien se observan varios outliers con kilometrajes muy elevados. Así mismo, para los vehículos con fraude se evidencia un rango más acotado de millas recorridas.
#
# -Para el precio_vehiculo, los casos sin fraude tienen vehículos con precios extremadamente altos que se acercan a 2.5 millones. Pero, en los casos de fraude se observa mayor concentración de vehículos en rangos de precio medio-alto.
#
# -Para el costo_reparacion, existen costos de repracion potencialmente altos en los casos de fraude, sin embargo la mayoría de los casos en ambos grupos tienen costos bajos, pero con más outliers en el grupo de fraude.
